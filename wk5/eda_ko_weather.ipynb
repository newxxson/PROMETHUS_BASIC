# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('weather.csv', encoding='CP949')

# %%
data.columns
# Out:
# Index(['지점', '지점명', '일시', '평균기온(°C)', '최저기온(°C)', '최저기온 시각(hhmi)', '최고기온(°C)',
#        '최고기온 시각(hhmi)', '일강수량(mm)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)',
#        '평균 풍속(m/s)', '풍정합(100m)', '최다풍향(16방위)', '평균 이슬점온도(°C)', '평균 상대습도(%)',
#        '평균 증기압(hPa)', '평균 현지기압(hPa)', '최고 해면기압(hPa)', '최저 해면기압(hPa)',
#        '평균 해면기압(hPa)', '합계 일조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)',
#        '평균 중하층운량(1/10)', '평균 지면온도(°C)', '최저 초상온도(°C)', '평균 30cm 지중온도(°C)',
#        '1.5m 지중온도(°C)', '합계 대형증발량(mm)'],
#       dtype='object')

# %%
data.head()
# Out:
#    지점 지점명          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0  90  속초  2011-01-01      -0.3      -5.0          100.0       1.7
# 1  90  속초  2011-01-02       0.9      -2.3          731.0       6.1
# 2  90  속초  2011-01-03      -0.6      -4.3         2351.0       3.8
# 3  90  속초  2011-01-04       0.2      -4.3          611.0       6.3
# 4  90  속초  2011-01-05      -0.6      -3.5         2339.0       3.8
#
#    최고기온 시각(hhmi)  일강수량(mm)  최대 풍속(m/s)  ...  평균 해면기압(hPa)  합계 일조시간(hr)  \
# 0         1534.0       1.8         6.3  ...        1021.3          0.0
# 1         1353.0       1.4         4.1  ...        1026.4          7.6
# 2         1309.0       8.8         3.3  ...        1023.0          3.3
# 3         1340.0       NaN         3.9  ...        1018.9          8.3
# 4         1255.0       NaN         7.7  ...        1017.0          7.3
#
#    합계 일사량(MJ/m2)  평균 전운량(1/10)  평균 중하층운량(1/10)  평균 지면온도(°C)  최저 초상온도(°C)  \
# 0            NaN           9.0             7.3         -1.9         -5.7
# 1            NaN           4.4             4.1         -0.8         -5.0
# 2            NaN           7.3             6.8         -0.1         -4.6
# 3            NaN           1.9             0.0         -0.8         -7.0
# 4            NaN           1.6             0.5         -1.3         -7.3
#
#    평균 30cm 지중온도(°C)  1.5m 지중온도(°C)  합계 대형증발량(mm)
# 0               NaN            NaN           NaN
# 1               NaN            NaN           NaN
# 2               NaN            NaN           NaN
# 3               NaN            NaN           NaN
# 4               NaN            NaN           NaN
#
# [5 rows x 30 columns]

# %%
data_columns = {'지점': 'location', 
                '지점명': 'location_name', 
                '일시': 'date', 
                '평균기온(°C)': 'avg_temp', 
                '최저기온(°C)': 'low_temp', 
                '최저기온 시각(hhmi)': 'low_temp_time', 
                '최고기온(°C)': 'high_temp',
                '최고기온 시각(hhmi)': 'high_temp_time', 
                '일강수량(mm)': 'rainfall', 
                '최대 풍속(m/s)': 'max_wind_speed', 
                '최대 풍속 풍향(16방위)': 'max_wind_direction',
                '평균 풍속(m/s)': 'avg_wind_speed',
                '풍정합(100m)': 'wind_sum',
                '최다풍향(16방위)': 'max_wind_direction', 
                '평균 이슬점온도(°C)': 'avg_dew_point_temp', 
                '평균 상대습도(%)': 'avg_humidity',
                '평균 증기압(hPa)': 'avg_vapor_pressure', 
                '평균 현지기압(hPa)': 'avg_pressure', 
                '최고 해면기압(hPa)': 'max_sea_pressure', 
                '최저 해면기압(hPa)': 'min_sea_pressure',
                '평균 해면기압(hPa)': 'avg_sea_pressure', 
                '합계 일조시간(hr)': 'total_sunlight', 
                '합계 일사량(MJ/m2)': 'total_solar_radiation',
                '평균 전운량(1/10)': 'avg_cloud',
                '평균 중하층운량(1/10)': 'avg_mid_low_cloud', 
                '평균 지면온도(°C)': 'avg_ground_temp', 
                '최저 초상온도(°C)': 'min_high_temp', # minimum grass temperature 땅 위에 접해 있는 풀 위의 공기온도를 말한다. 야간복사냉각에 의한 서리의 발생을 예상하는 가늠이 된다.
                '평균 30cm 지중온도(°C)': 'avg_30cm_ground_temp',
                '1.5m 지중온도(°C)': '1.5m_ground_temp', 
                '합계 대형증발량(mm)': 'total_evaporation',
            }

# %%
data.rename(columns=data_columns, inplace=True)
data.sample(10)
# Out:
#         location location_name        date  avg_temp  low_temp  low_temp_time  \
# 10350         98           동두천  2015-01-31      -5.8     -11.6          730.0
# 289776       271            봉화  2015-04-10       6.4      -1.7          431.0
# 143430       174            순천  2019-08-20      25.1      19.7          516.0
# 143452       174            순천  2019-09-11      25.0      22.0          359.0
# 252753       256            주암  2011-11-22       4.2      -3.2          659.0
# 213988       238            금산  2017-05-04      19.6      10.4          543.0
# 25074        102           백령도  2015-05-23      17.4      14.5           29.0
# 78804        135           추풍령  2012-06-22      23.5      16.6          545.0
# 312080       279            구미  2016-05-02      19.5      11.1          541.0
# 131242       169           흑산도  2016-01-09       4.0       2.5         1756.0
#
#         high_temp  high_temp_time  rainfall  max_wind_speed  ...  \
# 10350         1.7          1552.0       NaN             3.0  ...
# 289776       16.0          1253.0       NaN             4.1  ...
# 143430       30.1          1301.0       NaN             3.8  ...
# 143452       30.4          1451.0       0.7             3.7  ...
# 252753       10.7          1349.0       0.2             1.9  ...
# 213988       27.2          1552.0       NaN             3.3  ...
# 25074        23.5          1325.0       NaN             6.2  ...
# 78804        30.1          1627.0       NaN             5.6  ...
# 312080       26.6          1413.0       0.9             3.4  ...
# 131242        6.5          1338.0       0.0             6.2  ...
#
#         avg_sea_pressure  total_sunlight  total_solar_radiation  avg_cloud  \
# 10350             1032.2             9.6                    NaN        NaN
# 289776            1022.8             7.8                    NaN        NaN
# 143430            1009.0             7.5                    NaN        4.8
# 143452            1013.8             3.0                    NaN        8.0
# 252753            1027.3             2.6                    NaN        NaN
# 213988            1016.0             7.2                    NaN        NaN
# 25074             1011.8            13.2                    NaN        2.4
# 78804             1009.1             9.5                  22.64        NaN
# 312080            1013.2             NaN                    NaN        NaN
# 131242            1025.9             3.1                   6.86        6.1
#
#         avg_mid_low_cloud  avg_ground_temp  min_high_temp  \
# 10350                 NaN             -2.2          -13.8
# 289776                NaN              9.1           -3.9
# 143430                1.6             29.3           19.8
# 143452                5.0             28.4           21.3
# 252753                NaN              6.4           -6.8
# 213988                NaN             21.7            8.8
# 25074                 1.5             26.1           13.6
# 78804                 NaN             28.7           16.4
# 312080                NaN             22.4            6.1
# 131242                6.1              5.5            0.2
#
#         avg_30cm_ground_temp  1.5m_ground_temp  total_evaporation
# 10350                    NaN               NaN                NaN
# 289776                   NaN               NaN                NaN
# 143430                   NaN               NaN                NaN
# 143452                   NaN               NaN                NaN
# 252753                   NaN               NaN                NaN
# 213988                   NaN               NaN                NaN
# 25074                    NaN               NaN                NaN
# 78804                    NaN               NaN                NaN
# 312080                   NaN               NaN                NaN
# 131242                   NaN               NaN                NaN
#
# [10 rows x 30 columns]

# %%
data.groupby('location_name')['location'].count()
# Out:
# location_name
# 강릉     3653
# 강진군    3651
# 강화     3652
# 거제     3652
# 거창     3653
#        ...
# 합천     3653
# 해남     3653
# 홍성     1885
# 홍천     3653
# 흑산도    3653
# Name: location, Length: 98, dtype: int64

# %%
data['location_name'].nunique()
# Out:
# 98

# %%
data.groupby('location_name')['location'].count().sort_values(ascending=False)
# Out:
# location_name
# 강릉       3653
# 장수       3653
# 인천       3653
# 인제       3653
# 이천       3653
#          ...
# 홍성       1885
# 북춘천      1553
# 대구(기)     619
# 세종        581
# 주암        540
# Name: location, Length: 98, dtype: int64

# %%
data[data['location_name']=='서울']['location'].count()
# Out:
# 3653

# %%
len(data)
# Out:
# 343008

# %%
seoul = data[data['location_name']=='서울']
seoul.head(15)
# Out:
#        location location_name        date  avg_temp  low_temp  low_temp_time  \
# 38083       108            서울  2011-01-01      -6.8     -10.4          154.0
# 38084       108            서울  2011-01-02      -5.4      -8.5          621.0
# 38085       108            서울  2011-01-03      -4.5      -8.5          631.0
# 38086       108            서울  2011-01-04      -3.9      -7.4          648.0
# 38087       108            서울  2011-01-05      -4.0      -7.7         2353.0
# 38088       108            서울  2011-01-06      -7.6      -9.8          753.0
# 38089       108            서울  2011-01-07      -7.0     -10.6          753.0
# 38090       108            서울  2011-01-08      -3.6      -8.2          243.0
# 38091       108            서울  2011-01-09      -7.0     -10.3         2247.0
# 38092       108            서울  2011-01-10      -8.2     -11.8          538.0
# 38093       108            서울  2011-01-11      -5.4      -7.8          245.0
# 38094       108            서울  2011-01-12      -8.2     -11.1          803.0
# 38095       108            서울  2011-01-13      -5.9     -11.1          605.0
# 38096       108            서울  2011-01-14      -3.8      -6.9         2359.0
# 38097       108            서울  2011-01-15     -12.2     -15.7         2329.0
#
#        high_temp  high_temp_time  rainfall  max_wind_speed  ...  \
# 38083       -2.9          1457.0       NaN             4.7  ...
# 38084       -1.2          1455.0       NaN             4.2  ...
# 38085       -0.3          1525.0       NaN             4.8  ...
# 38086       -1.7          1355.0       NaN             4.8  ...
# 38087       -1.8          1208.0       NaN             8.0  ...
# 38088       -4.6          1607.0       NaN             5.1  ...
# 38089       -2.9          1502.0       NaN             4.5  ...
# 38090        0.1          1713.0       0.2             4.8  ...
# 38091       -0.3             0.0       0.0             6.5  ...
# 38092       -4.6          1443.0       NaN             5.4  ...
# 38093       -2.7          1942.0       1.9             7.5  ...
# 38094       -4.9          1548.0       NaN             6.7  ...
# 38095       -0.6          1553.0       NaN             4.4  ...
# 38096        0.3          1402.0       1.1             6.1  ...
# 38097       -6.9             0.0       NaN             8.0  ...
#
#        avg_sea_pressure  total_sunlight  total_solar_radiation  avg_cloud  \
# 38083            1023.0             8.8                   9.45        3.1
# 38084            1027.6             8.9                   9.73        0.0
# 38085            1023.3             7.1                   8.24        3.6
# 38086            1022.1             0.6                   5.93        5.8
# 38087            1021.5             5.0                   8.24        5.5
# 38088            1026.6             9.0                  10.70        0.0
# 38089            1028.9             9.1                  10.84        0.0
# 38090            1024.9             1.6                   5.35        7.5
# 38091            1026.2             8.9                  10.98        1.9
# 38092            1026.7             8.0                  10.89        3.1
# 38093            1018.0             0.0                   3.57        8.1
# 38094            1023.4             9.1                  11.74        0.0
# 38095            1026.6             8.0                  10.77        1.6
# 38096            1026.1             2.7                   7.11        7.5
# 38097            1027.2             8.6                  11.75        0.9
#
#        avg_mid_low_cloud  avg_ground_temp  min_high_temp  \
# 38083                1.3             -3.5          -18.1
# 38084                0.0             -3.4          -15.3
# 38085                0.0             -3.1          -15.1
# 38086                5.4             -2.7          -16.1
# 38087                5.5             -1.7          -10.1
# 38088                0.0             -4.0          -13.6
# 38089                0.0             -5.0          -16.6
# 38090                6.0             -3.4          -15.0
# 38091                0.9             -3.1          -14.7
# 38092                0.5             -5.8          -18.5
# 38093                7.8             -3.8          -11.7
# 38094                0.0             -3.3          -14.8
# 38095                1.6             -4.3          -18.6
# 38096                4.1             -2.3          -10.6
# 38097                0.5             -6.0          -17.4
#
#        avg_30cm_ground_temp  1.5m_ground_temp  total_evaporation
# 38083                  -0.1              10.0                NaN
# 38084                  -0.1               9.7                NaN
# 38085                  -0.1               9.6                NaN
# 38086                  -0.1               9.5                NaN
# 38087                  -0.1               9.4                NaN
# 38088                  -0.1               9.3                NaN
# 38089                  -0.3               9.2                NaN
# 38090                  -0.5               9.1                NaN
# 38091                  -0.2               9.1                NaN
# 38092                  -0.6               8.9                NaN
# 38093                  -0.7               8.8                NaN
# 38094                  -0.4               8.7                NaN
# 38095                  -0.8               8.6                NaN
# 38096                  -0.5               8.4                NaN
# 38097                  -0.8               8.4                NaN
#
# [15 rows x 30 columns]

# %%
seoul = seoul.drop(['location', 'location_name'], axis=1)
seoul.reset_index(drop=True, inplace=True)
seoul.head(15)
# Out:
#           date  avg_temp  low_temp  low_temp_time  high_temp  high_temp_time  \
# 0   2011-01-01      -6.8     -10.4          154.0       -2.9          1457.0
# 1   2011-01-02      -5.4      -8.5          621.0       -1.2          1455.0
# 2   2011-01-03      -4.5      -8.5          631.0       -0.3          1525.0
# 3   2011-01-04      -3.9      -7.4          648.0       -1.7          1355.0
# 4   2011-01-05      -4.0      -7.7         2353.0       -1.8          1208.0
# 5   2011-01-06      -7.6      -9.8          753.0       -4.6          1607.0
# 6   2011-01-07      -7.0     -10.6          753.0       -2.9          1502.0
# 7   2011-01-08      -3.6      -8.2          243.0        0.1          1713.0
# 8   2011-01-09      -7.0     -10.3         2247.0       -0.3             0.0
# 9   2011-01-10      -8.2     -11.8          538.0       -4.6          1443.0
# 10  2011-01-11      -5.4      -7.8          245.0       -2.7          1942.0
# 11  2011-01-12      -8.2     -11.1          803.0       -4.9          1548.0
# 12  2011-01-13      -5.9     -11.1          605.0       -0.6          1553.0
# 13  2011-01-14      -3.8      -6.9         2359.0        0.3          1402.0
# 14  2011-01-15     -12.2     -15.7         2329.0       -6.9             0.0
#
#     rainfall  max_wind_speed  max_wind_direction  avg_wind_speed  ...  \
# 0        NaN             4.7               290.0             1.9  ...
# 1        NaN             4.2               270.0             1.9  ...
# 2        NaN             4.8               270.0             2.1  ...
# 3        NaN             4.8               270.0             2.2  ...
# 4        NaN             8.0               250.0             3.8  ...
# 5        NaN             5.1               270.0             2.9  ...
# 6        NaN             4.5               290.0             2.1  ...
# 7        0.2             4.8               270.0             2.5  ...
# 8        0.0             6.5               270.0             4.1  ...
# 9        NaN             5.4               270.0             2.4  ...
# 10       1.9             7.5               290.0             2.5  ...
# 11       NaN             6.7               270.0             3.4  ...
# 12       NaN             4.4               250.0             1.8  ...
# 13       1.1             6.1               290.0             3.4  ...
# 14       NaN             8.0               270.0             4.9  ...
#
#     avg_sea_pressure  total_sunlight  total_solar_radiation  avg_cloud  \
# 0             1023.0             8.8                   9.45        3.1
# 1             1027.6             8.9                   9.73        0.0
# 2             1023.3             7.1                   8.24        3.6
# 3             1022.1             0.6                   5.93        5.8
# 4             1021.5             5.0                   8.24        5.5
# 5             1026.6             9.0                  10.70        0.0
# 6             1028.9             9.1                  10.84        0.0
# 7             1024.9             1.6                   5.35        7.5
# 8             1026.2             8.9                  10.98        1.9
# 9             1026.7             8.0                  10.89        3.1
# 10            1018.0             0.0                   3.57        8.1
# 11            1023.4             9.1                  11.74        0.0
# 12            1026.6             8.0                  10.77        1.6
# 13            1026.1             2.7                   7.11        7.5
# 14            1027.2             8.6                  11.75        0.9
#
#     avg_mid_low_cloud  avg_ground_temp  min_high_temp  avg_30cm_ground_temp  \
# 0                 1.3             -3.5          -18.1                  -0.1
# 1                 0.0             -3.4          -15.3                  -0.1
# 2                 0.0             -3.1          -15.1                  -0.1
# 3                 5.4             -2.7          -16.1                  -0.1
# 4                 5.5             -1.7          -10.1                  -0.1
# 5                 0.0             -4.0          -13.6                  -0.1
# 6                 0.0             -5.0          -16.6                  -0.3
# 7                 6.0             -3.4          -15.0                  -0.5
# 8                 0.9             -3.1          -14.7                  -0.2
# 9                 0.5             -5.8          -18.5                  -0.6
# 10                7.8             -3.8          -11.7                  -0.7
# 11                0.0             -3.3          -14.8                  -0.4
# 12                1.6             -4.3          -18.6                  -0.8
# 13                4.1             -2.3          -10.6                  -0.5
# 14                0.5             -6.0          -17.4                  -0.8
#
#     1.5m_ground_temp  total_evaporation
# 0               10.0                NaN
# 1                9.7                NaN
# 2                9.6                NaN
# 3                9.5                NaN
# 4                9.4                NaN
# 5                9.3                NaN
# 6                9.2                NaN
# 7                9.1                NaN
# 8                9.1                NaN
# 9                8.9                NaN
# 10               8.8                NaN
# 11               8.7                NaN
# 12               8.6                NaN
# 13               8.4                NaN
# 14               8.4                NaN
#
# [15 rows x 28 columns]

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   3653 non-null   object
#  1   avg_temp               3653 non-null   float64
#  2   low_temp               3653 non-null   float64
#  3   low_temp_time          3653 non-null   float64
#  4   high_temp              3652 non-null   float64
#  5   high_temp_time         3652 non-null   float64
#  6   rainfall               1412 non-null   float64
#  7   max_wind_speed         3651 non-null   float64
#  8   max_wind_direction     3651 non-null   float64
#  9   avg_wind_speed         3650 non-null   float64
#  10  wind_sum               3650 non-null   float64
#  11  max_wind_direction     3648 non-null   float64
#  12  avg_dew_point_temp     3653 non-null   float64
#  13  avg_humidity           3653 non-null   float64
#  14  avg_vapor_pressure     3653 non-null   float64
#  15  avg_pressure           3652 non-null   float64
#  16  max_sea_pressure       3652 non-null   float64
#  17  min_sea_pressure       3651 non-null   float64
#  18  avg_sea_pressure       3652 non-null   float64
#  19  total_sunlight         3642 non-null   float64
#  20  total_solar_radiation  3629 non-null   float64
#  21  avg_cloud              3653 non-null   float64
#  22  avg_mid_low_cloud      3632 non-null   float64
#  23  avg_ground_temp        3652 non-null   float64
#  24  min_high_temp          3650 non-null   float64
#  25  avg_30cm_ground_temp   3628 non-null   float64
#  26  1.5m_ground_temp       3644 non-null   float64
#  27  total_evaporation      2801 non-null   float64
# dtypes: float64(27), object(1)
# memory usage: 799.2+ KB

# %%
time_data = pd.to_datetime(seoul['date'], format='%Y-%m-%d')

# %%
seoul['year'] = time_data.dt.year
seoul['month'] = time_data.dt.month
seoul['day'] = time_data.dt.day
seoul
# Out:
#             date  avg_temp  low_temp  low_temp_time  high_temp  \
# 0     2011-01-01      -6.8     -10.4          154.0       -2.9
# 1     2011-01-02      -5.4      -8.5          621.0       -1.2
# 2     2011-01-03      -4.5      -8.5          631.0       -0.3
# 3     2011-01-04      -3.9      -7.4          648.0       -1.7
# 4     2011-01-05      -4.0      -7.7         2353.0       -1.8
# ...          ...       ...       ...            ...        ...
# 3648  2020-12-27       5.8       1.4            1.0       10.0
# 3649  2020-12-28       6.7       4.2          826.0       11.4
# 3650  2020-12-29       0.1      -6.2         2356.0        4.3
# 3651  2020-12-30     -10.9     -12.9         2222.0       -6.2
# 3652  2020-12-31      -8.9     -12.9          116.0       -5.0
#
#       high_temp_time  rainfall  max_wind_speed  max_wind_direction  \
# 0             1457.0       NaN             4.7               290.0
# 1             1455.0       NaN             4.2               270.0
# 2             1525.0       NaN             4.8               270.0
# 3             1355.0       NaN             4.8               270.0
# 4             1208.0       NaN             8.0               250.0
# ...              ...       ...             ...                 ...
# 3648          1412.0       0.0             2.8                50.0
# 3649          1344.0       1.3             3.1               290.0
# 3650             6.0       0.2             6.1               320.0
# 3651             1.0       NaN             6.2               270.0
# 3652          1512.0       0.0             4.2               250.0
#
#       avg_wind_speed  ...  avg_cloud  avg_mid_low_cloud  avg_ground_temp  \
# 0                1.9  ...        3.1                1.3             -3.5
# 1                1.9  ...        0.0                0.0             -3.4
# 2                2.1  ...        3.6                0.0             -3.1
# 3                2.2  ...        5.8                5.4             -2.7
# 4                3.8  ...        5.5                5.5             -1.7
# ...              ...  ...        ...                ...              ...
# 3648             1.8  ...        7.5                4.9              1.4
# 3649             1.4  ...        5.3                2.4              2.7
# 3650             2.9  ...        8.5                5.5             -0.1
# 3651             4.1  ...        0.8                0.8             -4.4
# 3652             2.4  ...        0.4                0.3             -5.0
#
#       min_high_temp  avg_30cm_ground_temp  1.5m_ground_temp  \
# 0             -18.1                  -0.1              10.0
# 1             -15.3                  -0.1               9.7
# 2             -15.1                  -0.1               9.6
# 3             -16.1                  -0.1               9.5
# 4             -10.1                  -0.1               9.4
# ...             ...                   ...               ...
# 3648           -0.9                   1.7              10.3
# 3649           -0.6                   2.1              10.1
# 3650           -6.6                   2.7              10.0
# 3651          -14.0                   2.4               9.9
# 3652          -14.5                   1.8               9.8
#
#       total_evaporation  year  month  day
# 0                   NaN  2011      1    1
# 1                   NaN  2011      1    2
# 2                   NaN  2011      1    3
# 3                   NaN  2011      1    4
# 4                   NaN  2011      1    5
# ...                 ...   ...    ...  ...
# 3648                1.2  2020     12   27
# 3649                1.3  2020     12   28
# 3650                0.8  2020     12   29
# 3651                0.9  2020     12   30
# 3652                0.8  2020     12   31
#
# [3653 rows x 31 columns]

# %%
seoul = seoul[seoul.columns.tolist()[-3:]+seoul.columns.tolist()[1:-3]]
seoul
# Out:
#       year  month  day  avg_temp  low_temp  low_temp_time  high_temp  \
# 0     2011      1    1      -6.8     -10.4          154.0       -2.9
# 1     2011      1    2      -5.4      -8.5          621.0       -1.2
# 2     2011      1    3      -4.5      -8.5          631.0       -0.3
# 3     2011      1    4      -3.9      -7.4          648.0       -1.7
# 4     2011      1    5      -4.0      -7.7         2353.0       -1.8
# ...    ...    ...  ...       ...       ...            ...        ...
# 3648  2020     12   27       5.8       1.4            1.0       10.0
# 3649  2020     12   28       6.7       4.2          826.0       11.4
# 3650  2020     12   29       0.1      -6.2         2356.0        4.3
# 3651  2020     12   30     -10.9     -12.9         2222.0       -6.2
# 3652  2020     12   31      -8.9     -12.9          116.0       -5.0
#
#       high_temp_time  rainfall  max_wind_speed  ...  avg_sea_pressure  \
# 0             1457.0       NaN             4.7  ...            1023.0
# 1             1455.0       NaN             4.2  ...            1027.6
# 2             1525.0       NaN             4.8  ...            1023.3
# 3             1355.0       NaN             4.8  ...            1022.1
# 4             1208.0       NaN             8.0  ...            1021.5
# ...              ...       ...             ...  ...               ...
# 3648          1412.0       0.0             2.8  ...            1021.6
# 3649          1344.0       1.3             3.1  ...            1023.1
# 3650             6.0       0.2             6.1  ...            1021.9
# 3651             1.0       NaN             6.2  ...            1023.8
# 3652          1512.0       0.0             4.2  ...            1026.6
#
#       total_sunlight  total_solar_radiation  avg_cloud  avg_mid_low_cloud  \
# 0                8.8                   9.45        3.1                1.3
# 1                8.9                   9.73        0.0                0.0
# 2                7.1                   8.24        3.6                0.0
# 3                0.6                   5.93        5.8                5.4
# 4                5.0                   8.24        5.5                5.5
# ...              ...                    ...        ...                ...
# 3648             5.9                   8.12        7.5                4.9
# 3649             8.0                   9.12        5.3                2.4
# 3650             0.0                   1.98        8.5                5.5
# 3651             8.3                  11.36        0.8                0.8
# 3652             6.0                   9.06        0.4                0.3
#
#       avg_ground_temp  min_high_temp  avg_30cm_ground_temp  1.5m_ground_temp  \
# 0                -3.5          -18.1                  -0.1              10.0
# 1                -3.4          -15.3                  -0.1               9.7
# 2                -3.1          -15.1                  -0.1               9.6
# 3                -2.7          -16.1                  -0.1               9.5
# 4                -1.7          -10.1                  -0.1               9.4
# ...               ...            ...                   ...               ...
# 3648              1.4           -0.9                   1.7              10.3
# 3649              2.7           -0.6                   2.1              10.1
# 3650             -0.1           -6.6                   2.7              10.0
# 3651             -4.4          -14.0                   2.4               9.9
# 3652             -5.0          -14.5                   1.8               9.8
#
#       total_evaporation
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 3648                1.2
# 3649                1.3
# 3650                0.8
# 3651                0.9
# 3652                0.8
#
# [3653 rows x 32 columns]

# %%
seoul.isnull().sum()
# Out:
# year                        0
# month                       0
# day                         0
# avg_temp                    0
# low_temp                    0
# low_temp_time               0
# high_temp                   1
# high_temp_time              1
# rainfall                 2241
# max_wind_speed              2
# max_wind_direction          2
# max_wind_direction          5
# avg_wind_speed              3
# wind_sum                    3
# max_wind_direction          2
# max_wind_direction          5
# avg_dew_point_temp          0
# avg_humidity                0
# avg_vapor_pressure          0
# avg_pressure                1
# max_sea_pressure            1
# min_sea_pressure            2
# avg_sea_pressure            1
# total_sunlight             11
# total_solar_radiation      24
# avg_cloud                   0
# avg_mid_low_cloud          21
# avg_ground_temp             1
# min_high_temp               3
# avg_30cm_ground_temp       25
# 1.5m_ground_temp            9
# total_evaporation         852
# dtype: int64

# %%
data['rainfall'].isnull().sum()/len(data)
# Out:
# 0.6347607052896725
